# %%
import pandas as pd

# %%
df=pd.read_csv('Messy_pharma.csv')

# %%
df
# Out:
#     MonthName    Year StockiestCode        StockiestName ProductCode  \
# 0       March  2022.0      AB557613  medico distributors      PRD911
# 1     January  2022.0      AB991249        Lifeline Meds      PRD857
# 2     January  2023.0      AB463755         Zenith Drugs      PRD446
# 3       April  2024.0      AB263215        BlueCross Med      PRD446
# 4       March  2023.0      AB991249      CureWell Pharma      PRD954
# ..        ...     ...           ...                  ...         ...
# 195  February  2022.0      AB697650        Lifeline Meds      PRD789
# 196   January  2022.0      AB114511         pulse pharma      PRD446
# 197  February  2022.0      AB253519    BetterLife Pharma      PRD144
# 198     April  2024.0      AB691907        BlueCross Med      PRD446
# 199  February  2024.0      AB697980         TrustMed Inc      PRD751
#
#                ProductName      ScanProductName  OpeningQuantity  \
# 0       Herbal Cough Syrup                  NaN              299
# ...

# %%
df.isnull().any()
# Out:
# MonthName            False
# Year                  True
# StockiestCode        False
# StockiestName        False
# ProductCode          False
# ProductName          False
# ScanProductName       True
# OpeningQuantity      False
# ReceiptQuantity       True
# IntransitQuantity     True
# ClosingQuantity      False
# SalesQuantity        False
# dtype: bool

# %% [markdown]
# ## checking	for	null	values	in	ScanProductName ##

# %%
df[df['ScanProductName'].isna()==1]
# Out:
#     MonthName    Year StockiestCode          StockiestName ProductCode  \
# 0       March  2022.0      AB557613    medico distributors      PRD911
# 2     January  2023.0      AB463755           Zenith Drugs      PRD446
# 10    January  2024.0      AB512147           Pulse Pharma      PRD914
# 11      March  2023.0      AB991249         Prime Medicals      PRD396
# 14      April  2022.0      AB394675           Sunrise Meds      PRD528
# 26   February  2023.0      AB912424           Pulse Pharma      PRD763
# 27   February  2023.0      AB831874         OmniPharm Ltd.      PRD895
# 33      March  2024.0      AB114511         OmniPharm Ltd.      PRD617
# 43   February  2024.0      AB467618           Zenith Drugs      PRD976
# 47      March  2024.0      AB657126  Careplus Distributors      PRD347
# 52    January  2023.0      AB697650       trumed solutions      PRD914
# 54      April  2022.0      AB512147     GoodHealth Traders      PRD455
# ...

# %% [markdown]
# ##  replacing	null	values	with	0 and NotFound ##

# %%
df['ScanProductName'] = df['ScanProductName'].fillna('NotFound')

# %%
df[df['Year'].isna()==1]
# Out:
#     MonthName  Year StockiestCode          StockiestName ProductCode  \
# 8       March   NaN      AB691907         omnipharm ltd.      PRD736
# 9       March   NaN      AB394675     global health corp      PRD731
# 36      March   NaN      AB263215  Careplus Distributors      PRD780
# 40      April   NaN      AB557613           Zenith Drugs      PRD476
# 42      March   NaN      AB831874      betterlife pharma      PRD647
# 73      March   NaN      AB463755     Global Health Corp      PRD826
# 81      April   NaN      AB852944           Pulse Pharma      PRD780
# 82    January   NaN      AB852944    medico distributors      PRD885
# 92   February   NaN      AB852944      Sterling Remedies      PRD575
# 93    January   NaN      AB697980         omnipharm ltd.      PRD250
# 103     March   NaN      AB697650       TruMed Solutions      PRD881
# 110  February   NaN      AB831874    Medico Distributors      PRD999
# 114   January   NaN      AB840718           zenith drugs      PRD899
# ...

# %%
df['Year']=df['Year'].fillna(0)

# %%
df.isnull().any()
# Out:
# MonthName            False
# Year                 False
# StockiestCode        False
# StockiestName        False
# ProductCode          False
# ProductName          False
# ScanProductName      False
# OpeningQuantity      False
# ReceiptQuantity       True
# IntransitQuantity     True
# ClosingQuantity      False
# SalesQuantity        False
# dtype: bool

# %%
df
# Out:
#     MonthName    Year StockiestCode        StockiestName ProductCode  \
# 0       March  2022.0      AB557613  medico distributors      PRD911
# 1     January  2022.0      AB991249        Lifeline Meds      PRD857
# 2     January  2023.0      AB463755         Zenith Drugs      PRD446
# 3       April  2024.0      AB263215        BlueCross Med      PRD446
# 4       March  2023.0      AB991249      CureWell Pharma      PRD954
# ..        ...     ...           ...                  ...         ...
# 195  February  2022.0      AB697650        Lifeline Meds      PRD789
# 196   January  2022.0      AB114511         pulse pharma      PRD446
# 197  February  2022.0      AB253519    BetterLife Pharma      PRD144
# 198     April  2024.0      AB691907        BlueCross Med      PRD446
# 199  February  2024.0      AB697980         TrustMed Inc      PRD751
#
#                ProductName      ScanProductName  OpeningQuantity  \
# 0       Herbal Cough Syrup             NotFound              299
# ...

# %% [markdown]
# ## Creating	New	coloumn	from	'YEAR'	and	'MONTHNAME' ##

# %%
df['Month'] = df['MonthName'].astype(str) + '-' + df['Year'].astype(str)

# %%
df=df.drop('MonthName', axis=1)

# %%
df=df.drop('Year', axis=1)

# %%
df['Month'] = df['Month'].astype(str).str.replace('.0', '')

# %%
df
# Out:
#     StockiestCode        StockiestName ProductCode            ProductName  \
# 0        AB557613  medico distributors      PRD911     Herbal Cough Syrup
# 1        AB991249        Lifeline Meds      PRD857         Immune Booster
# 2        AB463755         Zenith Drugs      PRD446   Motion Sickness Tabs
# 3        AB263215        BlueCross Med      PRD446        Laxative Powder
# 4        AB991249      CureWell Pharma      PRD954       Digestive Enzyme
# ..            ...                  ...         ...                    ...
# 195      AB697650        Lifeline Meds      PRD789        Pain Relief Gel
# 196      AB114511         pulse pharma      PRD446  Diabetes Care Tablets
# 197      AB253519    BetterLife Pharma      PRD144      Amoxicillin 250mg
# 198      AB691907        BlueCross Med      PRD446    Cholesterol Control
# 199      AB697980         TrustMed Inc      PRD751     HeartCare Capsules
#
#          ScanProductName  OpeningQuantity  ReceiptQuantity IntransitQuantity  \
# ...

# %%
df['StockiestName'].unique()
# Out:
# array(['medico distributors', 'Lifeline Meds', 'Zenith Drugs',
#        'BlueCross Med', 'CureWell Pharma', 'Global Health Corp',
#        'lifeline meds', 'Sterling Remedies', 'omnipharm ltd.',
#        'global health corp', 'Pulse Pharma', 'Prime Medicals',
#        'Sunrise Meds', 'OmniPharm Ltd.', 'alpha pharma', 'Nova Lifecare',
#        'Alpha Pharma', 'HealMore Agency', 'GoodHealth Traders',
#        'trumed solutions', 'Medico Distributors', 'healmore agency',
#        'Careplus Distributors', 'prime medicals', 'betterlife pharma',
#        'nova lifecare', 'sterling remedies', 'Vision Healthcare',
#        'BetterLife Pharma', 'zenith drugs', 'TruMed Solutions',
#        'pulse pharma', 'goodhealth traders', 'TrustMed Inc',
#        'bluecross med', 'careplus distributors', 'sunrise meds',
#        'curewell pharma'], dtype=object)

# %%
df['StockiestName'] = df['StockiestName'].str.strip().str.lower()

# %%
name_map = {
    'medico distributors': 'Medico Distributors',
    'Medico Distributors': 'Medico Distributors',

    'lifeline meds': 'Lifeline Meds',
    'Lifeline Meds': 'Lifeline Meds',

    'zenith drugs': 'Zenith Drugs',
    'Zenith Drugs': 'Zenith Drugs',

    'bluecross med': 'BlueCross Med',
    'BlueCross Med': 'BlueCross Med',

    'curewell pharma': 'CureWell Pharma',
    'CureWell Pharma': 'CureWell Pharma',

    'global health corp': 'Global Health Corp',
    'Global Health Corp': 'Global Health Corp',

    'sterling remedies': 'Sterling Remedies',
    'Sterling Remedies': 'Sterling Remedies',

    'omnipharm ltd.': 'OmniPharm Ltd.',
    'OmniPharm Ltd.': 'OmniPharm Ltd.',

    'pulse pharma': 'Pulse Pharma',
    'Pulse Pharma': 'Pulse Pharma',

    'prime medicals': 'Prime Medicals',
    'Prime Medicals': 'Prime Medicals',

    'sunrise meds': 'Sunrise Meds',
    'Sunrise Meds': 'Sunrise Meds',

    'alpha pharma': 'Alpha Pharma',
    'Alpha Pharma': 'Alpha Pharma',

    'nova lifecare': 'Nova Lifecare',
    'Nova Lifecare': 'Nova Lifecare',

    'healmore agency': 'HealMore Agency',
    'HealMore Agency': 'HealMore Agency',

    'goodhealth traders': 'GoodHealth Traders',
    'GoodHealth Traders': 'GoodHealth Traders',

    'trumed solutions': 'TruMed Solutions',
    'TruMed Solutions': 'TruMed Solutions',

    'careplus distributors': 'Careplus Distributors',
    'Careplus Distributors': 'Careplus Distributors',

    'betterlife pharma': 'BetterLife Pharma',
    'BetterLife Pharma': 'BetterLife Pharma',

    'vision healthcare': 'Vision Healthcare',
    'Vision Healthcare': 'Vision Healthcare',

    'trustmed inc': 'TrustMed Inc',
    'TrustMed Inc': 'TrustMed Inc'
}

# %%
df['StockiestName'] = df['StockiestName'].replace(name_map)

# %%
df['StockiestName'].unique()
# Out:
# array(['Medico Distributors', 'Lifeline Meds', 'Zenith Drugs',
#        'BlueCross Med', 'CureWell Pharma', 'Global Health Corp',
#        'Sterling Remedies', 'OmniPharm Ltd.', 'Pulse Pharma',
#        'Prime Medicals', 'Sunrise Meds', 'Alpha Pharma', 'Nova Lifecare',
#        'HealMore Agency', 'GoodHealth Traders', 'TruMed Solutions',
#        'Careplus Distributors', 'BetterLife Pharma', 'Vision Healthcare',
#        'TrustMed Inc'], dtype=object)

# %%
df['ProductName'].unique()
# Out:
# array(['Herbal Cough Syrup', 'Immune Booster', 'Motion Sickness Tabs',
#        'Laxative Powder', 'Digestive Enzyme', 'Antacid Suspension',
#        'Vitamin D3 Tablets', 'Iron Supplement', 'Anti-Fungal Cream',
#        'Cough Syrup', 'Motion Sickn3ss T@bs', 'Fever Reducer',
#        'Wound Healing Spray', 'Skin Brightening Cream', 'Blood Purifier',
#        'Oral Rehydration Salts', 'N@s@l Spr@y', 'Baby Lotion',
#        'Nasal Spray', 'Menstrual Pain Relief', 'HeartCare Capsules',
#        'Skin Ointment', 'Gastric Relief Tabs', 'Joint Pain Oil',
#        'Allergy Tablets', 'Insulin Injection', 'Steroid Cream',
#        'Sl33p Aid T@bl3ts', 'Cholesterol Control', 'C@lcium T@bl3ts',
#        'Antiseptic Solution', 'Ear Drops', 'Dental Gel',
#        'B-Complex Tablets', 'Amoxicillin 250mg', 'Paracetamol 500mg',
#        'Liver Tonic', 'Energy Booster', 'Sleep Aid Tablets', 'Acne Gel',
#        'Calcium Tablets', 'Pain Relief Gel', 'Probiotic Capsules',
# ...

# %%
df['ProductName'] = df['ProductName'].str.strip().str.lower()

# %%
product_map = {
    'herbal cough syrup': 'Herbal Cough Syrup',
    'cough syrup': 'Herbal Cough Syrup',

    'immune booster': 'Immune Booster',
    'energy booster': 'Immune Booster',

    'motion sickness tabs': 'Motion Sickness Tablets',
    'motion sickn3ss t@bs': 'Motion Sickness Tablets',

    'laxative powder': 'Laxative Powder',

    'digestive enzyme': 'Digestive Enzyme',

    'antacid suspension': 'Antacid Suspension',

    'vitamin d3 tablets': 'Vitamin D3 Tablets',

    'iron supplement': 'Iron Supplement',

    'anti-fungal cream': 'Anti-Fungal Cream',

    'fever reducer': 'Fever Reducer',

    'wound healing spray': 'Wound Healing Spray',

    'skin brightening cream': 'Skin Brightening Cream',

    'blood purifier': 'Blood Purifier',

    'oral rehydration salts': 'Oral Rehydration Salts',

    'nasal spray': 'Nasal Spray',
    'n@s@l spr@y': 'Nasal Spray',

    'baby lotion': 'Baby Lotion',

    'menstrual pain relief': 'Menstrual Pain Relief',

    'heartcare capsules': 'HeartCare Capsules',

    'skin ointment': 'Skin Ointment',

    'gastric relief tabs': 'Gastric Relief Tablets',

    'joint pain oil': 'Joint Pain Oil',

    'allergy tablets': 'Allergy Tablets',

    'insulin injection': 'Insulin Injection',

    'steroid cream': 'Steroid Cream',

    'sl33p aid t@bl3ts': 'Sleep Aid Tablets',
    'sleep aid tablets': 'Sleep Aid Tablets',

    'cholesterol control': 'Cholesterol Control',

    'c@lcium t@bl3ts': 'Calcium Tablets',
    'calcium tablets': 'Calcium Tablets',

    'antiseptic solution': 'Antiseptic Solution',

    'ear drops': 'Ear Drops',

    'dental gel': 'Dental Gel',

    'b-complex tablets': 'B-Complex Tablets',

    'amoxicillin 250mg': 'Amoxicillin 250mg',

    'paracetamol 500mg': 'Paracetamol 500mg',

    'liver tonic': 'Liver Tonic',

    'acne gel': 'Acne Gel',

    'pain relief gel': 'Pain Relief Gel',

    'probiotic capsules': 'Probiotic Capsules',
    'probiotic c@psul3s': 'Probiotic Capsules',

    'thyroid support': 'Thyroid Support',

    'anti-malarial tabs': 'Anti-Malarial Tablets',

    'muscle relaxant': 'Muscle Relaxant',

    'cold relief tablets': 'Cold Relief Tablets',

    'eye drops': 'Eye Drops',

    'zincovit syrup': 'Zincovit Syrup',

    'anti-anxiety tabs': 'Anti-Anxiety Tablets',

    'multivitamin drops': 'Multivitamin Drops',

    'hair growth serum': 'Hair Growth Serum',

    'anti-hypertensive': 'Anti-Hypertensive',

    'di@b3t3s c@r3 t@bl3ts': 'Diabetes Care Tablets',
    'diabetes care tablets': 'Diabetes Care Tablets',
}

# %%
df['ProductName'] = df['ProductName'].replace(product_map)

# %%
df['ScanProductName'].unique()
# Out:
# array(['NotFound', 'Antiseptic Solution', 'Laxative Powder',
#        'Calcium Tablets', 'Dental Gel', 'Thyroid Support',
#        'Anti-Malarial Tabs', 'Herbal Cough Syrup', 'HeartCare Capsules',
#        'Iron Supplement', 'Blood Purifier', 'Skin Ointment',
#        'Anti-Hypertensive', 'Gastric Relief Tabs', 'Steroid Cream',
#        'Amoxicillin 250mg', 'Digestive Enzyme', 'Anti-Fungal Cream',
#        'Menstrual Pain Relief', 'Liver Tonic', 'Energy Booster',
#        'Diabetes Care Tablets', 'Anti-Anxiety Tabs', 'Muscle Relaxant',
#        'B-Complex Tablets', 'Paracetamol 500mg', 'Baby Lotion',
#        'Skin Brightening Cream', 'Antacid Suspension', 'Allergy Tablets',
#        'Zincovit Syrup', 'Acne Gel', 'Insulin Injection',
#        'Joint Pain Oil', 'Ear Drops', 'Cholesterol Control',
#        'Immune Booster', 'Cold Relief Tablets', 'Pain Relief Gel',
#        'Eye Drops', 'Probiotic Capsules', 'Cough Syrup',
#        'Multivitamin Drops', 'Motion Sickness Tabs',
# ...

# %%
df['ScanProductName'] = df['ScanProductName'].str.strip().str.lower()

# %%
scanproduct_map = {
    'Unknown Product': 'Product not listed',  
    'antiseptic solution': 'Antiseptic Solution',
    'laxative powder': 'Laxative Powder',
    'calcium tablets': 'Calcium Tablets',
    'dental gel': 'Dental Gel',
    'thyroid support': 'Thyroid Support',
    'anti-malarial tabs': 'Anti-Malarial Tablets',
    'herbal cough syrup': 'Herbal Cough Syrup',
    'heartcare capsules': 'HeartCare Capsules',
    'iron supplement': 'Iron Supplement',
    'blood purifier': 'Blood Purifier',
    'skin ointment': 'Skin Ointment',
    'anti-hypertensive': 'Anti-Hypertensive',
    'gastric relief tabs': 'Gastric Relief Tablets',
    'steroid cream': 'Steroid Cream',
    'amoxicillin 250mg': 'Amoxicillin 250mg',
    'digestive enzyme': 'Digestive Enzyme',
    'anti-fungal cream': 'Anti-Fungal Cream',
    'menstrual pain relief': 'Menstrual Pain Relief',
    'liver tonic': 'Liver Tonic',
    'energy booster': 'Energy Booster', 
    'diabetes care tablets': 'Diabetes Care Tablets',
    'anti-anxiety tabs': 'Anti-Anxiety Tablets',
    'muscle relaxant': 'Muscle Relaxant',
    'b-complex tablets': 'B-Complex Tablets',
    'paracetamol 500mg': 'Paracetamol 500mg',
    'baby lotion': 'Baby Lotion',
    'skin brightening cream': 'Skin Brightening Cream',
    'antacid suspension': 'Antacid Suspension',
    'allergy tablets': 'Allergy Tablets',
    'zincovit syrup': 'Zincovit Syrup',
    'acne gel': 'Acne Gel',
    'insulin injection': 'Insulin Injection',
    'joint pain oil': 'Joint Pain Oil',
    'ear drops': 'Ear Drops',
    'cholesterol control': 'Cholesterol Control',
    'immune booster': 'Immune Booster',
    'cold relief tablets': 'Cold Relief Tablets',
    'pain relief gel': 'Pain Relief Gel',
    'eye drops': 'Eye Drops',
    'probiotic capsules': 'Probiotic Capsules',
    'cough syrup': 'Cough Syrup', 
    'multivitamin drops': 'Multivitamin Drops',
    'motion sickness tabs': 'Motion Sickness Tablets',
    'oral rehydration salts': 'Oral Rehydration Salts',
    'sleep aid tablets': 'Sleep Aid Tablets',
    'vitamin d3 tablets': 'Vitamin D3 Tablets',
    'nasal spray': 'Nasal Spray',
    'hair growth serum': 'Hair Growth Serum',
    'fever reducer': 'Fever Reducer',
}

# %%
df['ScanProductName'] = df['ScanProductName'].replace(scanproduct_map)

# %%
df['ScanProductName'].unique()
# Out:
# array(['notfound', 'Antiseptic Solution', 'Laxative Powder',
#        'Calcium Tablets', 'Dental Gel', 'Thyroid Support',
#        'Anti-Malarial Tablets', 'Herbal Cough Syrup',
#        'HeartCare Capsules', 'Iron Supplement', 'Blood Purifier',
#        'Skin Ointment', 'Anti-Hypertensive', 'Gastric Relief Tablets',
#        'Steroid Cream', 'Amoxicillin 250mg', 'Digestive Enzyme',
#        'Anti-Fungal Cream', 'Menstrual Pain Relief', 'Liver Tonic',
#        'Energy Booster', 'Diabetes Care Tablets', 'Anti-Anxiety Tablets',
#        'Muscle Relaxant', 'B-Complex Tablets', 'Paracetamol 500mg',
#        'Baby Lotion', 'Skin Brightening Cream', 'Antacid Suspension',
#        'Allergy Tablets', 'Zincovit Syrup', 'Acne Gel',
#        'Insulin Injection', 'Joint Pain Oil', 'Ear Drops',
#        'Cholesterol Control', 'Immune Booster', 'Cold Relief Tablets',
#        'Pain Relief Gel', 'Eye Drops', 'Probiotic Capsules',
# ...

# %%
df
# Out:
#     StockiestCode        StockiestName ProductCode              ProductName  \
# 0        AB557613  Medico Distributors      PRD911       Herbal Cough Syrup
# 1        AB991249        Lifeline Meds      PRD857           Immune Booster
# 2        AB463755         Zenith Drugs      PRD446  Motion Sickness Tablets
# 3        AB263215        BlueCross Med      PRD446          Laxative Powder
# 4        AB991249      CureWell Pharma      PRD954         Digestive Enzyme
# ..            ...                  ...         ...                      ...
# 195      AB697650        Lifeline Meds      PRD789          Pain Relief Gel
# 196      AB114511         Pulse Pharma      PRD446    Diabetes Care Tablets
# 197      AB253519    BetterLife Pharma      PRD144        Amoxicillin 250mg
# 198      AB691907        BlueCross Med      PRD446      Cholesterol Control
# 199      AB697980         TrustMed Inc      PRD751       HeartCare Capsules
#
# ...

# %%
df.dtypes
# Out:
# StockiestCode         object
# StockiestName         object
# ProductCode           object
# ProductName           object
# ScanProductName       object
# OpeningQuantity        int64
# ReceiptQuantity      float64
# IntransitQuantity     object
# ClosingQuantity        int64
# SalesQuantity          int64
# Month                 object
# dtype: object

# %%
df['IntransitQuantity'] = df['IntransitQuantity'].replace({'unknown':'0'})

# %% [markdown]
# ## accepting	NULL	values	into	INT ##

# %%
df['IntransitQuantity'] = pd.to_numeric(df['IntransitQuantity']).astype('Int64')

# %%
df['ReceiptQuantity'] = pd.to_numeric(df['ReceiptQuantity']).astype('float64')

# %% [markdown]
# ## checking	how	many	coloumn	has	more	than	1	NULL	values	for	reevaluation ##

# %%
df[df[['OpeningQuantity', 'ReceiptQuantity', 'IntransitQuantity', 'SalesQuantity', 'ClosingQuantity']].isnull().sum(axis=1) > 1]
# Out:
#     StockiestCode StockiestName ProductCode      ProductName ScanProductName  \
# 114      AB840718  Zenith Drugs      PRD899  Calcium Tablets     Cough Syrup
#
#      OpeningQuantity  ReceiptQuantity  IntransitQuantity  ClosingQuantity  \
# 114              772              NaN               <NA>              435
#
#      SalesQuantity      Month
# 114            202  January-0

# %% [markdown]
# ##  funcation	to	re	calculate	the	null	values	and	assign	them	into	null	values ##

# %%
mask = df['OpeningQuantity'].isna() & df['ReceiptQuantity'].notna() & df['IntransitQuantity'].notna() & df['SalesQuantity'].notna() & df['ClosingQuantity'].notna()

df.loc[mask, 'OpeningQuantity'] = (
    df.loc[mask, 'ClosingQuantity']
    - df.loc[mask, 'ReceiptQuantity']
    + df.loc[mask, 'IntransitQuantity']
    - df.loc[mask, 'SalesQuantity']
).astype(int)

# %%
mask = df['ReceiptQuantity'].isna() & df['OpeningQuantity'].notna() & df['IntransitQuantity'].notna() & df['SalesQuantity'].notna() & df['ClosingQuantity'].notna()

df.loc[mask, 'ReceiptQuantity'] = (
    df.loc[mask, 'ClosingQuantity']
    - df.loc[mask, 'OpeningQuantity']
    - df.loc[mask, 'IntransitQuantity']
    + df.loc[mask, 'SalesQuantity']
).astype(float)

# %%
mask = df['IntransitQuantity'].isna() & df['OpeningQuantity'].notna() & df['ReceiptQuantity'].notna() & df['SalesQuantity'].notna() & df['ClosingQuantity'].notna()

df.loc[mask, 'IntransitQuantity'] = (
    df.loc[mask, 'ClosingQuantity']
    - df.loc[mask, 'OpeningQuantity']
    - df.loc[mask, 'ReceiptQuantity']
    + df.loc[mask, 'SalesQuantity']
).astype(int)

# %%
mask = df['SalesQuantity'].isna() & df['OpeningQuantity'].notna() & df['ReceiptQuantity'].notna() & df['IntransitQuantity'].notna() & df['ClosingQuantity'].notna()

df.loc[mask, 'SalesQuantity'] = (
    df.loc[mask, 'ClosingQuantity']
    - df.loc[mask, 'OpeningQuantity']
    - df.loc[mask, 'ReceiptQuantity']
    + df.loc[mask, 'IntransitQuantity']
).astype(int)

# %%
mask = df['ClosingQuantity'].isna() & df['OpeningQuantity'].notna() & df['ReceiptQuantity'].notna() & df['IntransitQuantity'].notna() & df['SalesQuantity'].notna()

df.loc[mask, 'ClosingQuantity'] = (
    df.loc[mask, 'OpeningQuantity']
    + df.loc[mask, 'ReceiptQuantity']
    - df.loc[mask, 'IntransitQuantity']
    - df.loc[mask, 'SalesQuantity']
).astype(int)

# %%
df
# Out:
#     StockiestCode        StockiestName ProductCode              ProductName  \
# 0        AB557613  Medico Distributors      PRD911       Herbal Cough Syrup
# 1        AB991249        Lifeline Meds      PRD857           Immune Booster
# 2        AB463755         Zenith Drugs      PRD446  Motion Sickness Tablets
# 3        AB263215        BlueCross Med      PRD446          Laxative Powder
# 4        AB991249      CureWell Pharma      PRD954         Digestive Enzyme
# ..            ...                  ...         ...                      ...
# 195      AB697650        Lifeline Meds      PRD789          Pain Relief Gel
# 196      AB114511         Pulse Pharma      PRD446    Diabetes Care Tablets
# 197      AB253519    BetterLife Pharma      PRD144        Amoxicillin 250mg
# 198      AB691907        BlueCross Med      PRD446      Cholesterol Control
# 199      AB697980         TrustMed Inc      PRD751       HeartCare Capsules
#
# ...
